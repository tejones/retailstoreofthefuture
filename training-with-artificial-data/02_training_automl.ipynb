# %%
import os

import h2o
from h2o.automl import H2OAutoML

# %%
h2o.init()

# %%
data_dir = 'data_0408_0'
train_file_path = os.path.join(data_dir, 'train.csv')

# %%
train_h2o = h2o.H2OFrame(train)
train_h2o.describe()
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Rows:3368814
# Cols:20
# <table>
# <thead>
# <tr><th>       </th><th>coupon_used        </th><th>cust_credit       </th><th>cust_mean_product_price  </th><th>cust_unique_coupons_used  </th><th>cust_mean_discount  </th><th>cust_unique_products_bought  </th><th>cust_total_products_bougth  </th><th>coupon_discount   </th><th>coupon_how_many   </th><th>coupon_days_valid  </th><th>coupon_mean_prod_price  </th><th>cust_gender_F      </th><th>cust_gender_M      </th><th>cust_age_mid      </th><th>cust_age_old      </th><th>cust_age_young     </th><th>coupon_type_buy_all  </th><th>coupon_type_buy_more  </th><th>coupon_type_department  </th><th>coupon_type_just_discount  </th></tr>
# </thead>
# <tbody>
# ...

# %%
y = 'coupon_used'
x = train_h2o.columns
x.remove(y)
train_h2o['coupon_used'] = train_h2o['coupon_used'].asfactor()

# %%
aml = H2OAutoML(max_models=10, seed=1, balance_classes=True)
aml.train(x=x, y=y, training_frame=train_h2o)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
aml.leaderboard
# Out:
# <table>
# <thead>
# <tr><th>model_id                                           </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">   aucpr</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_AutoML_20210408_164243   </td><td style="text-align: right;">0.803702</td><td style="text-align: right;"> 0.241951</td><td style="text-align: right;">0.502149</td><td style="text-align: right;">              0.310092</td><td style="text-align: right;">0.254671</td><td style="text-align: right;">0.0648575</td></tr>
# ...

# %%
h2o.get_model('GBM_4_AutoML_20210408_164243')
# Out:
# Model Details
# ...
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_4_AutoML_20210408_164243
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0               70.0                      70.0             578602.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        0.0       10.0    7.571429         1.0       994.0        654.6
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.2711710163001577
# RMSE: 0.5207408341009544
# LogLoss: 0.8622691624238035
# Mean Per-Class Error: 0.2690251558453727
# AUC: 0.8156996013643698
# AUCPR: 0.8394483144715442
# Gini: 0.6313992027287396
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.05733060682487723:
#                   0          1   Error                    Rate
# 0      0  1729723.0  1297628.0  0.4286   (1297628.0/3027351.0)
# 1      1   513782.0  2513447.0  0.1697    (513782.0/3027229.0)
# ...
